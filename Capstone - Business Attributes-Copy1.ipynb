# %%
# look at unique values across columns to find all nested data
holder = {}
for x in busid_sample:
    holder[x] = busid_sample[x].unique()
    
#business_att.AcceptsInsurance.unique()

# %%
import pandas as pd

# %%
import json
from pandas.io.json import json_normalize

# %%
# set display options to 22 columns
pd.set_option('display.max_columns', 22)

# %%
pd.set_option('max_colwidth', 800)

# %%
# read in json file
yelp_df = pd.read_json('/Users/krystlelee/Documents/yelp_academic_dataset_business_revised.json')

# %%
yelp_df.iloc[0,1]['BusinessParking']
# Out:
# "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}"

# %%
yelp_df.head(1)
# Out:
#              address  \
# 0  1314 44 Avenue NE
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                 attributes  \
# 0  {'BikeParking': 'False', 'BusinessAcceptsCreditCards': 'True', 'BusinessParking': '{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}', 'GoodForKids': 'True', 'HasTV': 'True', 'NoiseLevel': 'average', 'OutdoorSeating': 'False', 'RestaurantsAttire': 'casual', 'RestaurantsDelivery': 'False', 'RestaurantsGoodForGroups': 'True', 'RestaurantsPriceRange2': '2', 'RestaurantsReservations': 'True', 'RestaurantsTakeOut': 'True'}
#
#               business_id  \
# 0  Apn5Q_b6Nz61Tq4XzPdf9A
#
#                                                     categories     city  \
# 0  Tours, Breweries, Pizza, Restaurants, Food, Hotels & Travel  Calgary
#
#                                                                                                                                                 hours  \
# 0  {'Monday': '8:30-17:0', 'Tuesday': '11:0-21:0', 'Wednesday': '11:0-21:0', 'Thursday': '11:0-21:0', 'Friday': '11:0-21:0', 'Saturday': '11:0-21:0'}
#
#    is_open   latitude   longitude                  name neighborhood  \
# 0        1  51.091813 -114.031675  Minhas Micro Brewery
#
#   postal_code  review_count  stars state
# 0     T2E 6L6            24    4.0    AB

# %%
# set index of dataset to business id
yelp_df_busid = yelp_df.set_index('business_id')

# %%
yelp_df_busid.head(1)
# Out:
#                                   address  \
# business_id
# Apn5Q_b6Nz61Tq4XzPdf9A  1314 44 Avenue NE
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      attributes  \
# business_id
# Apn5Q_b6Nz61Tq4XzPdf9A  {'BikeParking': 'False', 'BusinessAcceptsCreditCards': 'True', 'BusinessParking': '{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}', 'GoodForKids': 'True', 'HasTV': 'True', 'NoiseLevel': 'average', 'OutdoorSeating': 'False', 'RestaurantsAttire': 'casual', 'RestaurantsDelivery': 'False', 'RestaurantsGoodForGroups': 'True', 'RestaurantsPriceRange2': '2', 'RestaurantsReservations': 'True', 'RestaurantsTakeOut': 'True'}
#
#                                                                          categories  \
# business_id
# Apn5Q_b6Nz61Tq4XzPdf9A  Tours, Breweries, Pizza, Restaurants, Food, Hotels & Travel
#
#                            city  \
# business_id
# Apn5Q_b6Nz61Tq4XzPdf9A  Calgary
#
#                                                                                                                                                                      hours  \
# business_id
# Apn5Q_b6Nz61Tq4XzPdf9A  {'Monday': '8:30-17:0', 'Tuesday': '11:0-21:0', 'Wednesday': '11:0-21:0', 'Thursday': '11:0-21:0', 'Friday': '11:0-21:0', 'Saturday': '11:0-21:0'}
#
#                         is_open   latitude   longitude                  name  \
# business_id
# Apn5Q_b6Nz61Tq4XzPdf9A        1  51.091813 -114.031675  Minhas Micro Brewery
#
#                        neighborhood postal_code  review_count  stars state
# business_id
# Apn5Q_b6Nz61Tq4XzPdf9A                  T2E 6L6            24    4.0    AB

# %%
# create new data frame with business ids as index and attributes as columns
# create empty dictionary
diction = {}
# iterate over the rows
for index, row in yelp_df_busid.iterrows():
    # add keys, values to the dictionary using business id and attributes row
    diction[index] = row['attributes']
# create data frame of business id and attributes, transpose
business_att = pd.DataFrame(diction).transpose()

# %%
# review top rows to see results
business_att.head(2)
# Out:
#                        AcceptsInsurance AgesAllowed Alcohol Ambience BYOB  \
# Apn5Q_b6Nz61Tq4XzPdf9A              NaN         NaN     NaN      NaN  NaN
# AjEbIBw6ZFfln7ePHha9PA              NaN         NaN    none      NaN  NaN
#
#                        BYOBCorkage BestNights BikeParking  \
# Apn5Q_b6Nz61Tq4XzPdf9A         NaN        NaN       False
# AjEbIBw6ZFfln7ePHha9PA         NaN        NaN       False
#
#                        BusinessAcceptsBitcoin BusinessAcceptsCreditCards  \
# Apn5Q_b6Nz61Tq4XzPdf9A                    NaN                       True
# AjEbIBw6ZFfln7ePHha9PA                    NaN                       True
#
#                                                                                             BusinessParking  \
# Apn5Q_b6Nz61Tq4XzPdf9A  {'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}
# AjEbIBw6ZFfln7ePHha9PA   {'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}
#
#                        ...  RestaurantsAttire RestaurantsCounterService  \
# Apn5Q_b6Nz61Tq4XzPdf9A ...             casual                       NaN
# AjEbIBw6ZFfln7ePHha9PA ...             casual                       NaN
#
#                        RestaurantsDelivery RestaurantsGoodForGroups  \
# Apn5Q_b6Nz61Tq4XzPdf9A               False                     True
# AjEbIBw6ZFfln7ePHha9PA               False                     True
#
#                        RestaurantsPriceRange2 RestaurantsReservations  \
# Apn5Q_b6Nz61Tq4XzPdf9A                      2                    True
# AjEbIBw6ZFfln7ePHha9PA                      2                   False
#
#                        RestaurantsTableService RestaurantsTakeOut Smoking  \
# Apn5Q_b6Nz61Tq4XzPdf9A                     NaN               True     NaN
# AjEbIBw6ZFfln7ePHha9PA                   False               True     NaN
#
#                        WheelchairAccessible WiFi
# Apn5Q_b6Nz61Tq4XzPdf9A                  NaN  NaN
# AjEbIBw6ZFfln7ePHha9PA                 True   no
#
# [2 rows x 39 columns]

# %%
# split

# %%
business_att.iloc[0,10]
# Out:
# "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}"

# %%
# create subset of business attribute table for practice wrangling
busid_sample = business_att.head(10)

# %%
# nested columns from attributes - WIP
# create empty dictionary
parking_keys = []
parking_values = []
parking_dict = {}
# iterate over the rows
for index, row in busid_sample.head(2).iterrows():
    # add keys, values to the dictionary using business id and attributes row
    parking_keys.append(index)
    parking_values.append(row)
    parking_dict[index] = row['AcceptsInsurance']

# %%
# create new data frame with business ids as index and BusinessParking as columns
# create empty dictionary
test = []
# iterate over the rows
for index, row in busid_sample.iterrows():
    # add keys, values to the dictionary using business id and attributes row
    #test[index] = row['BusinessParking']
    test.append(row['BusinessParking'])

# %%
test
# Out:
# ["{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  None,
#  nan,
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#  "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}"]

# %%
type(test)
# Out:
# list

# %%
pd.DataFrame(test)
# Out:
#                                                                                       0
# 0   {'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}
# 1    {'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}
# 2  {'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}
# 3                                                                                  None
# 4                                                                                   NaN
# 5   {'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}
# 6  {'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}
# 7  {'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}
# 8   {'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}
# 9  {'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}

# %%
busid_sample.head(5)
# Out:
#                        AcceptsInsurance AgesAllowed        Alcohol  \
# Apn5Q_b6Nz61Tq4XzPdf9A              NaN         NaN            NaN
# AjEbIBw6ZFfln7ePHha9PA              NaN         NaN           none
# O8S5hYJ1SMc8fA4QBtVujA              NaN         NaN  beer_and_wine
# bFzdJJ3wp3PZssNEsyU23g             None        None           None
# 8USyCYqpScwiNEb58Bt6CA              NaN         NaN            NaN
#
#                                                                                                                                                                 Ambience  \
# Apn5Q_b6Nz61Tq4XzPdf9A                                                                                                                                               NaN
# AjEbIBw6ZFfln7ePHha9PA                                                                                                                                               NaN
# O8S5hYJ1SMc8fA4QBtVujA  {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}
# bFzdJJ3wp3PZssNEsyU23g                                                                                                                                              None
# 8USyCYqpScwiNEb58Bt6CA                                                                                                                                               NaN
#
#                         BYOB BYOBCorkage BestNights BikeParking  \
# Apn5Q_b6Nz61Tq4XzPdf9A   NaN         NaN        NaN       False
# AjEbIBw6ZFfln7ePHha9PA   NaN         NaN        NaN       False
# O8S5hYJ1SMc8fA4QBtVujA   NaN         NaN        NaN        True
# bFzdJJ3wp3PZssNEsyU23g  None        None       None        None
# 8USyCYqpScwiNEb58Bt6CA   NaN         NaN        NaN         NaN
#
#                        BusinessAcceptsBitcoin BusinessAcceptsCreditCards  \
# Apn5Q_b6Nz61Tq4XzPdf9A                    NaN                       True
# AjEbIBw6ZFfln7ePHha9PA                    NaN                       True
# O8S5hYJ1SMc8fA4QBtVujA                    NaN                      False
# bFzdJJ3wp3PZssNEsyU23g                   None                       None
# 8USyCYqpScwiNEb58Bt6CA                    NaN                       True
#
#                                                                                              BusinessParking  \
# Apn5Q_b6Nz61Tq4XzPdf9A   {'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}
# AjEbIBw6ZFfln7ePHha9PA    {'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}
# O8S5hYJ1SMc8fA4QBtVujA  {'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}
# bFzdJJ3wp3PZssNEsyU23g                                                                                  None
# 8USyCYqpScwiNEb58Bt6CA                                                                                   NaN
#
#                         ...  RestaurantsAttire RestaurantsCounterService  \
# Apn5Q_b6Nz61Tq4XzPdf9A  ...             casual                       NaN
# AjEbIBw6ZFfln7ePHha9PA  ...             casual                       NaN
# O8S5hYJ1SMc8fA4QBtVujA  ...             casual                       NaN
# bFzdJJ3wp3PZssNEsyU23g  ...               None                      None
# 8USyCYqpScwiNEb58Bt6CA  ...                NaN                       NaN
#
#                        RestaurantsDelivery RestaurantsGoodForGroups  \
# Apn5Q_b6Nz61Tq4XzPdf9A               False                     True
# AjEbIBw6ZFfln7ePHha9PA               False                     True
# O8S5hYJ1SMc8fA4QBtVujA               False                     True
# bFzdJJ3wp3PZssNEsyU23g                None                     None
# 8USyCYqpScwiNEb58Bt6CA                 NaN                      NaN
#
#                        RestaurantsPriceRange2 RestaurantsReservations  \
# Apn5Q_b6Nz61Tq4XzPdf9A                      2                    True
# AjEbIBw6ZFfln7ePHha9PA                      2                   False
# O8S5hYJ1SMc8fA4QBtVujA                      2                    True
# bFzdJJ3wp3PZssNEsyU23g                   None                    None
# 8USyCYqpScwiNEb58Bt6CA                    NaN                     NaN
#
#                        RestaurantsTableService RestaurantsTakeOut Smoking  \
# Apn5Q_b6Nz61Tq4XzPdf9A                     NaN               True     NaN
# AjEbIBw6ZFfln7ePHha9PA                   False               True     NaN
# O8S5hYJ1SMc8fA4QBtVujA                    True              False     NaN
# bFzdJJ3wp3PZssNEsyU23g                    None               None    None
# 8USyCYqpScwiNEb58Bt6CA                     NaN                NaN     NaN
#
#                        WheelchairAccessible  WiFi
# Apn5Q_b6Nz61Tq4XzPdf9A                  NaN   NaN
# AjEbIBw6ZFfln7ePHha9PA                 True    no
# O8S5hYJ1SMc8fA4QBtVujA                  NaN  free
# bFzdJJ3wp3PZssNEsyU23g                 None  None
# 8USyCYqpScwiNEb58Bt6CA                  NaN   NaN
#
# [5 rows x 39 columns]

# %%
d = eval("{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}")

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-234-3449b472dc69> in <module>()
# ----> 1 pd.DataFrame(d)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7354     # figure out the index, if necessary
#    7355     if index is None:
# -> 7356         index = extract_index(arrays)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in extract_index(data)
#    7391
#    7392         if not indexes and not raw_lengths:
# -> 7393             raise ValueError('If using all scalar values, you must pass'
#    7394                              ' an index')
#    7395
#
# ValueError: If using all scalar values, you must pass an index
